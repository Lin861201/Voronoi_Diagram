# %%
import numpy as np
from scipy.spatial import Voronoi, voronoi_plot_2d
import matplotlib.pyplot as plt

# %%
# points = np.array([[375, 132],
#                 [212, 284],
#                 [70, 335],
#                 [352, 438]])

points = np.array([[0,0],[1,1]])
vor = Voronoi(points)
# Out:
# ---------------------------------------------------------------------------
# QhullError                                Traceback (most recent call last)
# C:\Users\110510~1\AppData\Local\Temp/ipykernel_12896/3432581433.py in <module>
#       5
#       6 points = np.array([[0,0],[1,1]])
# ----> 7 vor = Voronoi(points)
#
# qhull.pyx in scipy.spatial.qhull.Voronoi.__init__()
#
# qhull.pyx in scipy.spatial.qhull._Qhull.__init__()
#
# QhullError: QH6214 qhull input error: not enough points(2) to construct initial simplex (need 4)
#
# While executing:  | qhull v Qbb Qz Qc
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 2108058954  voronoi  Qbbound-last  Qz-infinity-point  Qcoplanar-keep
#   _pre-merge  _zero-centrum  Qinterior-keep  _maxoutside  0

# %%
vor.vertices
# Out:
# array([[ -13.81580137, -121.55576068],
#        [ 189.64937259,  444.95511583],
#        [ 365.43963175,  285.14578931]])

# %%
voronoi_plot_2d(vor)

# %%
plt.xlim(50, 58)
plt.ylim(11, 20)
voronoi_plot_2d(vor)
